# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)

# %%
# import os
# os.listdir()

# %%
# a = pd.read_csv('pub_metadata_marcos.csv')
# b = pd.read_csv('pub_metadata_andrew.csv')
# c = pd.read_csv('pub_metadata_jason.csv',encoding = 'utf-8-sig')
ncses_df = pd.read_csv('test.csv')

# %%
ncses_df
# Out:
#                                                                                                                                                                                                            title  \
# 0    A Battle Plan for Supporting Military Families, Lessons for the Leaders of Tomorrow
# 1    A comparison of two approaches for measuring interdisciplinary research output: The disciplinary diversity of authors vs the disciplinary diversity of the reference list
# 2    A conceptual framework for studying science research careers
# 3    A data-based guide to the North American ecology faculty job market
# 4    A National Study of the Influence of the Community College Pathway on Female StudentsaTM STEM Baccalaureate Success
# 5    A Review of Approaches Used to Increase Awareness of Pre-exposure Prophylaxis (PrEP) in the United States
# 6    Academic Entrepreneurship: The Bayh-Dole Act versus the ProfessoraTMs Privilege
# ...

# %%
ncses_df.loc[ncses_df['title'] == 'Doctoral student experiences in biological sciences laboratory rotations']
# Out:
#                                                                        title  \
# 31  Doctoral student experiences in biological sciences laboratory rotations
#
#         dataset  \
# 31  dataset-428
#
# ...

# %%
c = pd.read_csv('ncses_pub_metadata.csv')

# %%
c
# Out:
#                                                 title      dataset  \
# 0      Are transitions to self-employment beneficial?  dataset-370
# 1   Academic Entrepreneurship: The Bayh-Dole Act v...  dataset-370
# 2   Why foreign STEM PhDs are unlikely to work for...  dataset-370
# 3   Investigating the US biomedical workforce: gen...  dataset-370
# 4   On the nexus between innovation, productivity ...  dataset-370
# 5   Investigation of an equity ethic in engineerin...  dataset-370
# 6   A National Study of the Influence of the Commu...  dataset-370
# 7   The impact of the H-1B cap exemption on Ph.D. ...  dataset-370
# 8   Simulation of the leaky pipeline: Gender diver...  dataset-370
# 9   Does scientist immigration harm US science? An...  dataset-370
# 10  The changing career trajectories of new parent...  dataset-370
# 11  The Socialization of STEM Professionals Into S...  dataset-370
# 12  National health innovation systems: Clustering...  dataset-370
# ...
