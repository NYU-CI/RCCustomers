# %%
import os
from stat import S_ISREG, ST_CTIME, ST_MODE
import os, sys, time

# %%
files = os.listdir('/Users/sophierand/RichContextMetadata/metadata')
files
# Out:
# ['20191119_WashingtonTemporaryAssistanceforNeedyFamilies',
#  '20191119_UnemploymentInsurancewagedata',
#  '20191119_IllinoisDepartmentofCorrectionsInmateExits',
#  '20191119_CalWORKsWelfare-To-WorkMonthlyActivityReport-All(Other)Families',
#  '20191119_ArizonaUnemploymentInsurance',
#  '20191119_MarylandUnemploymentInsurance',
#  '20191119_MissouriUnemploymentInsurance',
#  '20191119_IllinoisWageData',
#  '20191119_SurveyofIncomeandProgramParticipation',
#  '20191119_Multi-SamplePersonFile',
#  '20191119_WorkforceInvestmentActStandardizedRecordData',
#  '20191119_FLORIDAsystem',
#  '20191119_VocationalRehabilitationInitiative',
#  '20191118_ncses_fedreporter',
#  '20191119_SouthCarolinaTemporaryAssistanceforNeedyFamilies',
#  '20191119_MississippiWorkforceInformationDatabase',
#  '20191119_GeorgiaQCEW',
#  '20191119_MinnesotaUnemploymentInsurance',
#  '20191119_NewYorkStateDepartmentofLaborUnemploymentInsurance',
#  '20191119_ResearchandDevelopmentEnterpriseProjectdata',
# ...

# %%
# time.ctime(cdate), os.path.basename(path)

[(f,os.path.getmtime('/Users/sophierand/RichContextMetadata/metadata/'+f)) for f in files]
# Out:
# [('20191119_WashingtonTemporaryAssistanceforNeedyFamilies',
#   1574194101.3950884),
#  ('20191119_UnemploymentInsurancewagedata', 1574194336.7176666),
#  ('20191119_IllinoisDepartmentofCorrectionsInmateExits', 1574194639.0367377),
#  ('20191119_CalWORKsWelfare-To-WorkMonthlyActivityReport-All(Other)Families',
#   1574194634.03815),
#  ('20191119_ArizonaUnemploymentInsurance', 1574194450.790296),
#  ('20191119_MarylandUnemploymentInsurance', 1574194316.3087544),
#  ('20191119_MissouriUnemploymentInsurance', 1574194317.6046038),
#  ('20191119_SurveyofIncomeandProgramParticipation', 1574193964.4774728),
#  ('20191119_Multi-SamplePersonFile', 1574194043.276775),
#  ('20191119_WorkforceInvestmentActStandardizedRecordData', 1574194571.6851997),
#  ('20191119_FLORIDAsystem', 1574194245.215139),
#  ('20191119_VocationalRehabilitationInitiative', 1574194422.880526),
#  ('20191118_ncses_fedreporter', 1574107108.2548854),
#  ('20191119_SouthCarolinaTemporaryAssistanceforNeedyFamilies',
# ...

# %%
for cdate, path in sorted(files):
    print(cdate)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-c3c3e1e28e54> in <module>
# ----> 1 for cdate, path in sorted(files):
#       2     print(cdate)
#
# ValueError: too many values to unpack (expected 2)
