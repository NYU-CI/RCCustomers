# %%
TTL_HEADER = """                                                                                                             
@base <https://github.com/Coleridge-Initiative/adrf-onto/wiki/Vocabulary> .                                                  
@prefix cito:   <http://purl.org/spar/cito/> .                                                                               
@prefix dct:    <http://purl.org/dc/terms/> .                                                                                
@prefix foaf:   <http://xmlns.com/foaf/0.1/> .                                                                               
@prefix rdf:    <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .                                                              
@prefix xsd:    <http://www.w3.org/2001/XMLSchema#> .                                                                        
"""

PUB_TEMPLATE = """                                                                                                           
:{}                                                                                                                          
  rdf:type :ResearchPublication ;                                                                                            
  dct:title "{}"@en ;                                                                                                        
  dct:identifier "{}" ;                                                                                                      
  dct:language "en" ;                                                                                                        
  foaf:page "{}"^^xsd:anyURI ;                                                                                               
  .                                                                                                                          
"""

# %%
from rdflib import Graph, plugin
from rdflib.plugin import register, Parser, Serializer
import pyld
import json

# format as JSON_LD                                                                                                      
with open("vocab.json", "r") as f:
    CONTEXT = json.load(f)

frags = [TTL_HEADER]

# %%
usda_ds_0_100_path = '/Users/sophierand/RCCustomers/exports/USDA/ds_application/metadata_partitions/20191017_usda_pubs_md.json'
# usda_ds_0_100 = 
with open(usda_ds_0_100_path) as json_file:
    usda_ds_0_100 = json.load(json_file)

# %%
a = usda_ds_0_100[0:3]
a
# Out:
# [{'title': 'Supply-side subsidies to improve food access and dietary outcomes: Evidence from the New Markets Tax Credit',
#   'datasets': ['dataset-002'],
#   'original': {'doi': '10.1177/0042098017740285',
#    'dataset_name': 'IRI Consumer Network',
#    'journal': 'Urban Studies',
#    'url': 'https://www.doi.org/10.1177/0042098017740285',
#    'date_added': '2019-10-14 16:34:18'},
#   'dimensions': {'linkout': 'https://www.economics.uci.edu/research/wp/1718/17-18-04.pdf',
#    'authors': [{'first_name': 'Matthew',
#      'last_name': 'Freedman',
#      'corresponding': '',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': '',
#      'affiliations': [{'id': 'grid.266093.8',
#        'name': 'University of California, Irvine',
#        'city': 'Irvine',
#        'city_id': 5359777,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'California',
#        'state_code': 'US-CA'}]},
#     {'first_name': 'Annemarie',
#      'last_name': 'Kuhns',
#      'corresponding': '',
#      'orcid': '',
#      'current_organization_id': 'grid.482913.5',
#      'researcher_id': 'ur.010072134242.80',
#      'affiliations': [{'id': 'grid.482913.5',
#        'name': 'Economic Research Service',
#        'city': 'Washington D.C.',
#        'city_id': 4140963,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'District of Columbia',
#        'state_code': 'US-DC'}]}],
#    'doi': '10.1177/0042098017740285',
#    'keywords': ['eligibility',
#     'efforts',
#     'investment',
#     'area',
#     'supermarkets',
#     'entry',
#     'shopping',
#     'tax credits',
#     'supply-side subsidies',
#     'retailers',
#     'positive impact',
#     'income areas',
#     'food access',
#     'outcomes',
#     'subsidies',
#     'health outcomes',
#     'neighborhood',
#     'food shopping',
#     'funding',
#     'household-level scanner data',
#     'article',
#     'establishment',
#     'income communities',
#     'retail food establishments',
#     'census tracts',
#     'impact',
#     'advantages',
#     'run',
#     'low-income communities',
#     'New Markets Tax Credits',
#     'food retailers',
#     'program',
#     'policymakers',
#     'data',
#     'access',
#     'credit',
#     'low-income areas',
#     'scanner data',
#     'short run',
#     'dietary outcomes',
#     'evidence',
#     'effects',
#     'purchasing patterns',
#     'community',
#     'households'],
#    'journal_title': 'Urban Studies',
#    'title': 'Supply-side subsidies to improve food access and dietary outcomes: Evidence from the New Markets Tax Credit'}},
#  {'title': 'The healthfulness of food and beverage purchases after the federal food package revisions: The case of two New England states',
#   'datasets': ['dataset-002'],
#   'original': {'doi': '10.1016/j.ypmed.2016.08.018',
#    'dataset_name': 'IRI Consumer Network',
#    'journal': 'Preventive Medicine',
#    'url': 'https://www.doi.org/10.1016/j.ypmed.2016.08.018',
#    'date_added': '2019-10-14 16:34:18'},
#   'dimensions': {'authors': [{'first_name': 'Tatiana',
#      'last_name': 'Andreyeva',
#      'corresponding': True,
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': 'ur.01204326301.31',
#      'affiliations': [{'name': 'Department of Agricultural and Resource Economics, Rudd Center for Food Policy Obesity, University of Connecticut, Hartford, CT, United States'}]},
#     {'first_name': 'Amanda S.',
#      'last_name': 'Tripp',
#      'corresponding': '',
#      'orcid': '',
#      'current_organization_id': 'grid.47100.32',
#      'researcher_id': 'ur.01330330105.77',
#      'affiliations': [{'id': 'grid.47100.32',
#        'name': 'Yale University',
#        'city': 'New Haven',
#        'city_id': 4839366,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Connecticut',
#        'state_code': 'US-CT'},
#       {'id': 'grid.429534.d',
#        'name': 'Lewin Group',
#        'city': 'Falls Church',
#        'city_id': 4758390,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'Virginia',
#        'state_code': 'US-VA'}]}],
#    'doi': '10.1016/j.ypmed.2016.08.018',
#    'keywords': ['improvement',
#     'assistance',
#     'infants',
#     'participants',
#     'sodium content',
#     'people',
#     'Supplemental Nutrition Program',
#     'food volume',
#     'volume',
#     'cases',
#     'whole grains',
#     'WIC food package revisions',
#     'healthfulness',
#     'comparison group',
#     'healthy food purchases',
#     'WIC',
#     'comparison households',
#     'WIC participants',
#     'food packages',
#     'food',
#     'vegetables',
#     'fat restriction',
#     'New England states',
#     'healthy eating',
#     'food purchases',
#     'pre-post assessment',
#     'beverages',
#     'low-income nonparticipants',
#     'assessment',
#     'fat',
#     'restriction',
#     'children',
#     'revision',
#     'beverage purchases',
#     'regional supermarket chain',
#     'reduction',
#     'healthfulness of foods',
#     'eating',
#     'nonparticipants',
#     'federal food assistance',
#     'WIC revisions',
#     'women',
#     'program',
#     'intake',
#     'baseline',
#     'new food packages',
#     'post assessment',
#     'healthy products',
#     'Special Supplemental Nutrition Program',
#     'similar improvements',
#     'data',
#     'England states',
#     'saturated fat',
#     'group',
#     'Nutrition Program',
#     'food assistance',
#     'participant purchases',
#     'dietary intake',
#     'items'],
#    'journal_title': 'Preventive Medicine',
#    'title': 'The healthfulness of food and beverage purchases after the federal food package revisions: The case of two New England states'},
#   'europepmc': {'doi': '10.1016/j.ypmed.2016.08.018',
#    'journal': 'Prev Med',
#    'url': 'http://europepmc.org/abstract/MED/27527573',
#    'title': 'the healthfulness of food and beverage purchases after the federal food package revisions: the case of two new england states'}},
#  {'title': 'A comparative analysis of hedonic models of nutrition information and health claims on food products: An application to soup products',
#   'datasets': ['dataset-001'],
#   'original': {'doi': '10.1080/10454446.2018.1428259',
#    'dataset_name': 'IRI InfoScan',
#    'journal': 'Journal of Food Products Marketing',
#    'url': 'https://www.doi.org/10.1080/10454446.2018.1428259',
#    'date_added': '2019-10-14 16:34:18'},
#   'dimensions': {'authors': [{'first_name': 'Kristen C.',
#      'last_name': 'Giombi',
#      'corresponding': '',
#      'orcid': '',
#      'current_organization_id': 'grid.62562.35',
#      'researcher_id': 'ur.013165016127.50',
#      'affiliations': [{'id': 'grid.62562.35',
#        'name': 'RTI International',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'Mary K.',
#      'last_name': 'Muth',
#      'corresponding': '',
#      'orcid': "['0000-0001-7879-0469']",
#      'current_organization_id': 'grid.62562.35',
#      'researcher_id': 'ur.0617027742.93',
#      'affiliations': [{'id': 'grid.62562.35',
#        'name': 'RTI International',
#        'city': 'Durham',
#        'city_id': 4464368,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'North Carolina',
#        'state_code': 'US-NC'}]},
#     {'first_name': 'David',
#      'last_name': 'Levin',
#      'corresponding': '',
#      'orcid': '',
#      'current_organization_id': '',
#      'researcher_id': '',
#      'affiliations': [{'id': 'grid.482913.5',
#        'name': 'Economic Research Service',
#        'city': 'Washington D.C.',
#        'city_id': 4140963,
#        'country': 'United States',
#        'country_code': 'US',
#        'state': 'District of Columbia',
#        'state_code': 'US-DC'}]}],
#    'doi': '10.1080/10454446.2018.1428259',
#    'keywords': ['purchase',
#     'nutrition information',
#     'health claims',
#     'purpose',
#     'organic claims',
#     'product attributes',
#     'food products',
#     'claims',
#     'quality',
#     'detailed data',
#     'prices',
#     'study',
#     'better understanding',
#     'information',
#     'analysis',
#     'food purchases',
#     'availability',
#     'product claims',
#     'attributes',
#     'quality of data',
#     'extensive data',
#     'model',
#     'values',
#     'data sources',
#     'different data sources',
#     'implications',
#     'comparative analysis',
#     'data',
#     'effects',
#     'consumers',
#     'results'],
#    'journal_title': 'Journal of Food Products Marketing',
#    'title': 'A comparative analysis of hedonic models of nutrition information and health claims on food products: An application to soup products'}}]

# %%
[
    "10.1111/agec.12444",
    "publication-e84ab84d25278051773e",
    "http://purl.umn.edu/205424",
    "Agricultural Economics",
    "Does a nutritious diet cost more in food deserts?"
  ]

# %%
for doi, pub_id, pub_url, journal, title in results:
    frags.append(PUB_TEMPLATE.format(pub_id, title, doi, pub_url))

g = Graph()
g.parse(data="\n".join(frags), format="n3")

jsonld = json.loads(g.serialize(format="json-ld", context=CONTEXT))
jsonld = pyld.jsonld.compact(jsonld, CONTEXT)

print(json.dumps(jsonld, indent=2))
